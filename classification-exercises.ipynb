# %% [markdown]
# ### Exercises

# %% [markdown]
# Use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.
#
# - print the first 3 rows
# - print the number of rows and columns (shape)
# - print the column names
# - print the data type of each column
# - print the summary statistics for each of the numeric variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pydataset import data
from env import get_db_url

iris_df = data('iris')

iris_df.info()
print(iris_df.iloc[0:3])
print(iris_df.shape)
print(iris_df.columns)
print(iris_df.dtypes)
#print(f'Sepal Length summary stats: Mean {iris_df.iloc[:, 0].mean()}, Median {iris_df.iloc[:, 0].median()}, Std Dev {iris_df.iloc[:, 0].std()}, Max {iris_df.iloc[:, 0].max()}, Min {iris_df.iloc[:, 0].min()}')
#print(f'Sepal Width summary stats: Mean {iris_df.iloc[:, 1].mean()}, Median {iris_df.iloc[:, 1].median()}, Std Dev {iris_df.iloc[:, 1].std()}, Max {iris_df.iloc[:, 1].max()}, Min {iris_df.iloc[:, 1].min()}')
#print(f'Petal Length summary stats: Mean {iris_df.iloc[:, 2].mean()}, Median {iris_df.iloc[:, 2].median()}, Std Dev {iris_df.iloc[:, 2].std()}, Max {iris_df.iloc[:, 2].max()}, Min {iris_df.iloc[:, 2].min()}')
#print(f'Petal Width summary stats: Mean {iris_df.iloc[:, 3].mean()}, Median {iris_df.iloc[:, 3].median()}, Std Dev {iris_df.iloc[:, 3].std()}, Max {iris_df.iloc[:, 3].max()}, Min {iris_df.iloc[:, 3].min()}')
print(iris_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# (150, 5)
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# ...

# %% [markdown]
# Read the Table1_CustDetails table from your spreadsheet exercises google sheet into a dataframe named df_google_sheets.
#
# Make sure that the spreadsheet is publicly visible under your sharing settings.
#
# - assign the first 100 rows to a new dataframe, df_google_sheets_sample
# - print the number of rows of your original dataframe
# - print the first 5 column names
# - print the column names that have a data type of object
# - compute the range for each of the numeric variables.

# %%
df_google_sheets = pd.read_clipboard()
df_google_sheets.head()

# assign first 100 rows to sample
df_google_sheets_sample = df_google_sheets.head(100)
# print number of rows of original df
print(f'Rows in DF: {len(df_google_sheets)}')
# print first 5 column names
print(f'First five column names: {df_google_sheets.iloc[:, 0:4].columns}')
# print column names that have data type == object
print(f'Data type == object: {df_google_sheets.select_dtypes(include=object).columns}')
# compute the range for each of the numeric variables
df_google_sheets.describe()

google_sheets_nums = df_google_sheets.select_dtypes(include='number')
gs_nums_df = pd.DataFrame(google_sheets_nums.describe())

gs_nums_df

range_gs_nums = gs_nums_df.loc['max'] - gs_nums_df.loc['min']
range_gs_nums
print(f'The ranges for the numeric columns in the \"Google Sheets DF\" are as follows:\n{range_gs_nums}')
# Out:
# Rows in DF: 0
# First five column names: Index(['print('Getting', 'a', 'fresh', 'copy'], dtype='object')
# Data type == object: Index(['print('Getting', 'a', 'fresh', 'copy', 'from', 'SQL', 'db...')'], dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qq/jwr_4nc14hb3rbj39kp4nm5h0000gn/T/ipykernel_24022/3544260371.py in <module>
#      14
#      15 google_sheets_nums = df_google_sheets.select_dtypes(include='number')
# ---> 16 gs_nums_df = pd.DataFrame(google_sheets_nums.describe())
#      17
#      18 gs_nums_df
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10022         max            NaN      3.0
#   10023         """
# > 10024         return describe_ndframe(
#   10025             obj=self,
#   10026             include=include,
#
# ...

# %% [markdown]
# Read the data from "this google sheet" (train) into a dataframe, df_google
#
# - print the first 3 rows
# - print the number of rows and columns
# - print the column names
# - print the data type of each column
# - print the summary statistics for each of the numeric variables
# - print the unique values for each of your categorical variables

# %%
df_google = pd.read_clipboard()

df_google.info()
df_google.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   print('Getting  0 non-null      object
#  1   a               0 non-null      object
#  2   fresh           0 non-null      object
#  3   copy            0 non-null      object
#  4   from            0 non-null      object
#  5   SQL             0 non-null      object
#  6   db...')         0 non-null      object
# dtypes: object(7)
# memory usage: 0.0+ bytes
# Empty DataFrame
# Columns: [print('Getting, a, fresh, copy, from, SQL, db...')]
# Index: []

# %%
# first 3 rows
print(df_google.iloc[0:3])
# Out:
#     Read  the    data   from  this google    sheet  into     a dataframe,  \
# 0  print  the   first      3  rows   None     None  None  None       None
# 1  print  the  number     of  rows    and  columns  None  None       None
# 2  print  the  column  names  None   None     None  None  None       None
#
#    df_google
# 0        NaN
# 1        NaN
# 2        NaN

# %%
# first 3 rows and columns
print(df_google.iloc[0:3, 0:3])
# Out:
#     Read  the    data
# 0  print  the   first
# 1  print  the  number
# 2  print  the  column

# %%
# column names
print(df_google.columns)
# Out:
# Index(['Read', 'the', 'data', 'from', 'this', 'google', 'sheet', 'into', 'a',
#        'dataframe,', 'df_google'],
#       dtype='object')

# %%
# summary statistics
print(df_google.describe())
# Out:
#        df_google
# count        0.0
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN

# %%
# unique values in categorical columns
df_google_cat = df_google.iloc[:, 0:10]
print(df_google_cat.nunique())
# Out:
# Read          1
# the           1
# data          6
# from          6
# this          3
# google        2
# sheet         3
# into          2
# a             2
# dataframe,    1
# dtype: int64

# %%
import acquire as acq

# %%
acq.get_titanic_data()
# Out:
# Reading from CSV file...
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class deck  embark_town  alone
# ...

# %%
acq.show_codeup_dbs()
# Out:
# List of Codeup DBs:
#               Database
# 0            albums_db
# 1             chipotle
# 2      curriculum_logs
# 3               elo_db
# 4            employees
# 5            fruits_db
# 6           grocery_db
# 7          home_credit
# 8   information_schema
# 9           innis_1673
# 10             iris_db
# 11     join_example_db
# 12                logs
# 13      mall_customers
# 14               mysql
# 15             numbers
# 16               pizza
# 17           quotes_db
# 18            saas_llc
# 19              sakila
# 20             spam_db
# 21       superstore_db
# 22              svi_db
# 23         telco_churn
# 24           tidy_data
# 25          titanic_db
# 26     tsa_item_demand
# 27               world
# 28              zillow

# %%
acq.get_iris_data()
# Out:
# Reading from CSV file...
#      measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0                 1           5.1          3.5           1.4          0.2
# 1                 2           4.9          3.0           1.4          0.2
# 2                 3           4.7          3.2           1.3          0.2
# 3                 4           4.6          3.1           1.5          0.2
# 4                 5           5.0          3.6           1.4          0.2
# 5                 6           5.4          3.9           1.7          0.4
# 6                 7           4.6          3.4           1.4          0.3
# 7                 8           5.0          3.4           1.5          0.2
# 8                 9           4.4          2.9           1.4          0.2
# 9                10           4.9          3.1           1.5          0.1
# 10               11           5.4          3.7           1.5          0.2
# ...

# %%
acq.get_telco_data()
# Out:
# Reading from CSV file...
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines  internet_service_type_id  \
# ...

# %%
url = get_db_url('titanic_db')
pd.read_sql('SHOW TABLES', url)
# Out:
#   Tables_in_titanic_db
# 0           passengers

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings('ignore')

# %%
iris_df = acq.get_iris_data()

iris_df.head()
# Out:
# Reading from CSV file...
#    measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0               1           5.1          3.5           1.4          0.2
# 1               2           4.9          3.0           1.4          0.2
# 2               3           4.7          3.2           1.3          0.2
# 3               4           4.6          3.1           1.5          0.2
# 4               5           5.0          3.6           1.4          0.2
#
#    species_id  species_id.1 species_name
# 0           1             1       setosa
# 1           1             1       setosa
# 2           1             1       setosa
# 3           1             1       setosa
# 4           1             1       setosa

# %% [markdown]
# ### Using the Iris Data:
#
# Use the function defined in acquire.py to load the iris data.
#
# Drop the species_id and measurement_id columns.
#
# Rename the species_name column to just species.
#
# Create dummy variables of the species name and concatenate onto the iris dataframe. (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).
#
# Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %% [markdown]
# Drop columns (species_id and measurement_id)

# %%
cols_to_drop = ['species_id', 'measurement_id']

iris_df = iris_df.drop(columns= (cols_to_drop))

# %% [markdown]
# Rename 'species_id.1' and 'species_name'

# %%
iris_df = iris_df.rename(columns= {'species_id.1': 'species_id', 'species_name': 'species'})
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species_id species
# 0           5.1          3.5           1.4          0.2           1  setosa
# 1           4.9          3.0           1.4          0.2           1  setosa
# 2           4.7          3.2           1.3          0.2           1  setosa
# 3           4.6          3.1           1.5          0.2           1  setosa
# 4           5.0          3.6           1.4          0.2           1  setosa

# %% [markdown]
# Create dummy variables for the species name and concatenate the dummy_df onto iris_df.

# %%
dummy_df = pd.get_dummies(iris_df[['species']], dummy_na=False, drop_first=[True])
dummy_df
iris_df = pd.concat([iris_df, dummy_df], axis=1)
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species_id  \
# 0             5.1          3.5           1.4          0.2           1
# 1             4.9          3.0           1.4          0.2           1
# 2             4.7          3.2           1.3          0.2           1
# 3             4.6          3.1           1.5          0.2           1
# 4             5.0          3.6           1.4          0.2           1
# 5             5.4          3.9           1.7          0.4           1
# 6             4.6          3.4           1.4          0.3           1
# 7             5.0          3.4           1.5          0.2           1
# 8             4.4          2.9           1.4          0.2           1
# 9             4.9          3.1           1.5          0.1           1
# 10            5.4          3.7           1.5          0.2           1
# 11            4.8          3.4           1.6          0.2           1
# ...

# %%
titanic_df = acq.get_titanic_data()
titanic_df.head()
titanic_df.info()
# Out:
# Reading from CSV file...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  891 non-null    int64
#  1   survived      891 non-null    int64
#  2   pclass        891 non-null    int64
#  3   sex           891 non-null    object
#  4   age           714 non-null    float64
#  5   sibsp         891 non-null    int64
#  6   parch         891 non-null    int64
#  7   fare          891 non-null    float64
#  8   embarked      889 non-null    object
#  9   class         891 non-null    object
#  10  deck          203 non-null    object
#  11  embark_town   889 non-null    object
#  12  alone         891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class deck  embark_town  alone
# 0        S  Third  NaN  Southampton      0
# 1        C  First    C    Cherbourg      0
# 2        S  Third  NaN  Southampton      1
# 3        S  First    C  Southampton      0
# 4        S  Third  NaN  Southampton      1

# %% [markdown]
# ### Using the Titanic dataset
#
# Use the function defined in acquire.py to load the Titanic data.
#
# Drop any unnecessary, unhelpful, or duplicated columns.
#
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.
#
# Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %% [markdown]
# Drop unnecessary, unhelpful, or duplicated columns.

# %%
titanic_df = titanic_df.drop_duplicates()
titanic_df = titanic_df.drop(columns= ['passenger_id', 'age', 'embarked', 'class', 'deck'])

# %%
print(titanic_df.shape)
titanic_df.info()
titanic_df.head()
# Out:
# (891, 8)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   sibsp        891 non-null    int64
#  4   parch        891 non-null    int64
#  5   fare         891 non-null    float64
#  6   embark_town  889 non-null    object
#  7   alone        891 non-null    int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 62.6+ KB
#    survived  pclass     sex  sibsp  parch     fare  embark_town  alone
# 0         0       3    male      1      0   7.2500  Southampton      0
# 1         1       1  female      1      0  71.2833    Cherbourg      0
# 2         1       3  female      0      0   7.9250  Southampton      1
# 3         1       1  female      1      0  53.1000  Southampton      0
# ...

# %% [markdown]
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the df.

# %%
titanic_df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# sibsp            int64
# parch            int64
# fare           float64
# embark_town     object
# alone            int64
# dtype: object

# %%
#Find nulls
print(f'Titanic DF has this many nulls:\n{titanic_df.isnull().sum()}')
titanic_df.embark_town.value_counts()
# Out:
# Titanic DF has this many nulls:
# survived       0
# pclass         0
# sex            0
# sibsp          0
# parch          0
# fare           0
# embark_town    2
# alone          0
# dtype: int64
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
#fill nulls in embark_town with mode ('Southampton')
titanic_df = titanic_df.fillna('Southampton')
print(f'Titanic DF now has this many nulls:\n{titanic_df.isnull().sum()}')
# Out:
# Titanic DF now has this many nulls:
# survived       0
# pclass         0
# sex            0
# sibsp          0
# parch          0
# fare           0
# embark_town    0
# alone          0
# dtype: int64

# %%
titanic_dummy_df = pd.get_dummies(titanic_df[['sex', 'embark_town']], dummy_na=False, drop_first= [True, True])
titanic_dummy_df.head()
# Out:
#    sex_male  embark_town_Queenstown  embark_town_Southampton
# 0         1                       0                        1
# 1         0                       0                        0
# 2         0                       0                        1
# 3         0                       0                        1
# 4         1                       0                        1

# %%
titanic_df = pd.concat([titanic_df, titanic_dummy_df], axis=1)
titanic_df_clean = titanic_df.drop(columns= ['sex', 'embark_town'])
titanic_df_clean
# Out:
#      survived  pclass  sibsp  parch     fare  alone  sex_male  \
# 0           0       3      1      0   7.2500      0         1
# 1           1       1      1      0  71.2833      0         0
# 2           1       3      0      0   7.9250      1         0
# 3           1       1      1      0  53.1000      0         0
# 4           0       3      0      0   8.0500      1         1
# ..        ...     ...    ...    ...      ...    ...       ...
# 886         0       2      0      0  13.0000      1         1
# 887         1       1      0      0  30.0000      1         0
# 888         0       3      1      2  23.4500      0         0
# 889         1       1      0      0  30.0000      1         1
# 890         0       3      0      0   7.7500      1         1
#
#      embark_town_Queenstown  embark_town_Southampton
# 0                         0                        1
# 1                         0                        0
# 2                         0                        1
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 250)

# %% [markdown]
# ### Using the Telco dataset
#
# Use the function defined in acquire.py to load the Telco data.
#
# Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.
#
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.
#
# Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %%
telco_df = acq.get_telco_data()
telco_df.info()
telco_df.head()
# Out:
# Reading from CSV file...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 7043 non-null   object
#  1   gender                      7043 non-null   object
#  2   senior_citizen              7043 non-null   int64
#  3   partner                     7043 non-null   object
#  4   dependents                  7043 non-null   object
#  5   tenure                      7043 non-null   int64
#  6   phone_service               7043 non-null   object
#  7   multiple_lines              7043 non-null   object
#  8   internet_service_type_id    7043 non-null   int64
#  9   online_security             7043 non-null   object
#  10  online_backup               7043 non-null   object
#  11  device_protection           7043 non-null   object
# ...

# %%
telco_df.isnull().sum()
# Out:
# customer_id                   0
# gender                        0
# senior_citizen                0
# partner                       0
# dependents                    0
# tenure                        0
# phone_service                 0
# multiple_lines                0
# internet_service_type_id      0
# online_security               0
# online_backup                 0
# device_protection             0
# tech_support                  0
# streaming_tv                  0
# streaming_movies              0
# contract_type_id              0
# paperless_billing             0
# payment_type_id               0
# monthly_charges               0
# total_charges                 0
# churn                         0
# contract_type_id.1            0
# contract_type                 0
# payment_type_id.1             0
# payment_type                  0
# internet_service_type_id.1    0
# internet_service_type         0
# dtype: int64

# %% [markdown]
# Drop unnecessary, unhelpful, or duplicated columns.

# %%
telco_df = telco_df.drop_duplicates()
telco_df.shape
# Out:
# (7043, 27)

# %%
telco_df[['contract_type_id.1', 'contract_type_id', 'payment_type_id.1', 'payment_type_id', 'internet_service_type_id.1', 'internet_service_type_id']].head()
# Out:
#    contract_type_id.1  contract_type_id  payment_type_id.1  payment_type_id  \
# 0                   2                 2                  2                2
# 1                   1                 1                  2                2
# 2                   1                 1                  1                1
# 3                   1                 1                  1                1
# 4                   1                 1                  2                2
#
#    internet_service_type_id.1  internet_service_type_id
# 0                           1                         1
# 1                           1                         1
# 2                           2                         2
# 3                           2                         2
# 4                           2                         2

# %%
telco_df = telco_df.drop(columns= ['contract_type_id.1', 'payment_type_id.1', 'internet_service_type_id.1'])
telco_df.info()
telco_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               7043 non-null   object
#  1   gender                    7043 non-null   object
#  2   senior_citizen            7043 non-null   int64
#  3   partner                   7043 non-null   object
#  4   dependents                7043 non-null   object
#  5   tenure                    7043 non-null   int64
#  6   phone_service             7043 non-null   object
#  7   multiple_lines            7043 non-null   object
#  8   internet_service_type_id  7043 non-null   int64
#  9   online_security           7043 non-null   object
#  10  online_backup             7043 non-null   object
#  11  device_protection         7043 non-null   object
#  12  tech_support              7043 non-null   object
# ...

# %%
cat_cols = [col for col in telco_df.columns if telco_df[col].dtype == 'O']
telco_df[cat_cols].info()
telco_df[cat_cols].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            7043 non-null   object
#  1   gender                 7043 non-null   object
#  2   partner                7043 non-null   object
#  3   dependents             7043 non-null   object
#  4   phone_service          7043 non-null   object
#  5   multiple_lines         7043 non-null   object
#  6   online_security        7043 non-null   object
#  7   online_backup          7043 non-null   object
#  8   device_protection      7043 non-null   object
#  9   tech_support           7043 non-null   object
#  10  streaming_tv           7043 non-null   object
#  11  streaming_movies       7043 non-null   object
#  12  paperless_billing      7043 non-null   object
#  13  churn                  7043 non-null   object
# ...

# %%
telco_df.sort_values(by='total_charges').head()
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 2855  4075-WKNIU  Female               0     Yes        Yes       0
# 3118  4472-LVYGI  Female               0     Yes        Yes       0
# 3052  4367-NUYAO    Male               0     Yes        Yes       0
# 5433  7644-OMVMY    Male               0     Yes        Yes       0
# 1731  2520-SGTTA  Female               0     Yes        Yes       0
#
#      phone_service    multiple_lines  internet_service_type_id  \
# 2855           Yes               Yes                         1
# 3118            No  No phone service                         1
# 3052           Yes               Yes                         3
# 5433           Yes                No                         3
# 1731           Yes                No                         3
#
#           online_security        online_backup    device_protection  \
# 2855                   No                  Yes                  Yes
# ...

# %%
telco_df.loc[2855, 'total_charges']
# Out:
# ' '

# %%
telco_df.total_charges = telco_df.total_charges.replace(' ', np.nan).astype(float)
telco_df[cat_cols].info()
telco_df[cat_cols].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            7043 non-null   object
#  1   gender                 7043 non-null   object
#  2   partner                7043 non-null   object
#  3   dependents             7043 non-null   object
#  4   phone_service          7043 non-null   object
#  5   multiple_lines         7043 non-null   object
#  6   online_security        7043 non-null   object
#  7   online_backup          7043 non-null   object
#  8   device_protection      7043 non-null   object
#  9   tech_support           7043 non-null   object
#  10  streaming_tv           7043 non-null   object
#  11  streaming_movies       7043 non-null   object
#  12  paperless_billing      7043 non-null   object
#  13  churn                  7043 non-null   object
# ...

# %% [markdown]
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them to the DF.

# %%
print(f'Contract types:\n{telco_df.contract_type.value_counts()}')
print('----------------')
print(f'Payment types:\n{telco_df.payment_type.value_counts()}')
print('----------------')
print(f'Internet service types:\n{telco_df.internet_service_type.value_counts()}')
# Out:
# Contract types:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: contract_type, dtype: int64
# ----------------
# Payment types:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: payment_type, dtype: int64
# ----------------
# Internet service types:
# Fiber optic    3096
# DSL            2421
# None           1526
# Name: internet_service_type, dtype: int64

# %%
telco_cats = list(telco_df[cat_cols].columns)
telco_cats
#len(telco_cats)
# Out:
# ['customer_id',
#  'gender',
#  'partner',
#  'dependents',
#  'phone_service',
#  'multiple_lines',
#  'online_security',
#  'online_backup',
#  'device_protection',
#  'tech_support',
#  'streaming_tv',
#  'streaming_movies',
#  'paperless_billing',
#  'churn',
#  'contract_type',
#  'payment_type',
#  'internet_service_type']

# %%
telco_cats[:14]
# Out:
# ['customer_id',
#  'gender',
#  'partner',
#  'dependents',
#  'phone_service',
#  'multiple_lines',
#  'online_security',
#  'online_backup',
#  'device_protection',
#  'tech_support',
#  'streaming_tv',
#  'streaming_movies',
#  'paperless_billing',
#  'churn']
